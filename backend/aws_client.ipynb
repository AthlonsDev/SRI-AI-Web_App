# %%
import boto3

# %%
s3 = boto3.resource('s3')

# %%
s3 = boto3.resource(
    's3',
    aws_access_key_id='AKIA5N6KSCCMOEUZ4IWX',
    aws_secret_access_key='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'
)

# %%
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# sribucket00

# %%
# upload a file to a bucket
s3.Bucket('sribucket00').upload_file('requirements.txt', 'requirements')

# %%
# get a file from a bucket
s3.Bucket('sribucket00').download_file('requirements', 'downloaded_requirements.txt')
