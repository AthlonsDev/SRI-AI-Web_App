# %%
import boto3

# %%
s3 = boto3.resource('s3')

# %%
client = boto3.client(
    's3',
    aws_access_key_id='9233-0590-6328',
    aws_secret_access_key='9233-0590-4532'
)

# %%
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for bucket in s3.buckets.all():
#       2     print(bucket.name)
#
# File c:\Users\athlo\anaconda3\Lib\site-packages\boto3\resources\collection.py:79, in ResourceCollection.__iter__(self)
#      76 limit = self._params.get('limit', None)
#      78 count = 0
# ---> 79 for page in self.pages():
#      80     for item in page:
#      81         yield item
#
# File c:\Users\athlo\anaconda3\Lib\site-packages\boto3\resources\collection.py:169, in ResourceCollection.pages(self)
#     166 # Now that we have a page iterator or single page of results
#     167 # we start processing and yielding individual items.
#     168 count = 0
# --> 169 for page in pages:
#     170     page_items = []
#     171     for item in self._handler(self._parent, params, page):
#
# ...
